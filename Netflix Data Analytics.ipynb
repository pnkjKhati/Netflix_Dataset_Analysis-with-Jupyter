# %% [markdown]
# ## Netflix Dataset
#
#     This Netflix Dataset has information about the TV Shows and Mobies available on Netflix till 2021.
#     The dataset is collected from Flixable which is third-party Netflix search engine,and available on Kaggle website for
#     free.

# %%
# Importing the dataset
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('Netflix Dataset.csv', encoding='ISO-8859–1')

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  Joo Miguel, Bianca Comparato, Michel Gomes, Ro...         Brazil
# 1  Demin Bichir, Hctor Bonilla, Oscar Serrano, Az...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7784 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 334.7+ KB

# %% [markdown]
# ### Task 1. is there any Duplicate Record in this dataset? If yes, then remove the duplicate records.

# %%
data.shape
# Out:
# (7789, 11)

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#      Release_Date Rating Duration                                   Type  \
# 6300     5-Apr-19  TV-MA   97 min  Dramas, Independent Movies, Thrillers
# 6622     4-Sep-20  TV-MA   94 min   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace=True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# ### Task2.is there any Null Value present in any column? Show with Heat-map.

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  Joo Miguel, Bianca Comparato, Michel Gomes, Ro...
# ...

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              5
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Q.1 For 'House of Cards', what is the Show Id and Who is the Director of this show?

# %% [markdown]
# #### Using isin()

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demin Bichir, Hctor Bonilla, Oscar Serrano, Az...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...

# %%
data[data['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      Release_Date Rating   Duration                     Type  \
# 2832     2-Nov-18  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# #### Using str.contains()

# %%
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      Release_Date Rating   Duration                     Type  \
# 2832     2-Nov-18  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### Q2. In which year highest number of the TV Shows & Movies were released? Show with Bar Graph.

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# #### to_datetime

# %%
data['Date_N'] = pd.to_datetime(data['Release_Date'])                                        # Add new column with datetime type

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demin Bichir, Hctor Bonilla, Oscar Serrano, Az...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_N
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23
# 2  When an army recruit is found dead, his fellow... 2018-12-20

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %% [markdown]
# #### dt.year.value_counts()

# %%
data['Date_N'].dt.year.value_counts()                          # It counts the occurence of all individual Years in Date column.
# Out:
# 2019    1337
# 2020    1229
# 2018    1114
# 2017     752
# 2016     207
# 2021      78
# 2015      50
# 2014      14
# 2011      13
# 2013       7
# 2012       3
# 2009       2
# 2008       1
# 2010       1
# Name: Date_N, dtype: int64

# %% [markdown]
# #### Bar Graph

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Q.3. How many Movies & TV Shows are in the dataset? Show with Bar Graph

# %% [markdown]
# #### groupby()

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      4672
# TV Show     136
# Name: Category, dtype: int64

# %% [markdown]
# #### countplot()

# %%
sns.countplot(data['Category'])
# Out:
# c:\users\pankaj\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# ### Q.4 Show all the Movies that were released in year 2000.

# %% [markdown]
# #### Creating new column

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demin Bichir, Hctor Bonilla, Oscar Serrano, Az...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_N
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23
# 2  When an army recruit is found dead, his fellow... 2018-12-20

# %%
data['Year']= data['Date_N'].dt.year

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demin Bichir, Hctor Bonilla, Oscar Serrano, Az...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_N  Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018

# %% [markdown]
# #### Filtering

# %%
data[(data['Category']=='Movie') & (data['Year']==2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
data[(data['Category']=='Movie') & (data['Year']==2020)]
# Out:
#      Show_Id Category                          Title  \
# 4         s5    Movie                             21
# 6         s7    Movie                            122
# 14       s15    Movie                           3022
# 27       s28    Movie                         #Alive
# 28       s29    Movie  #AnneFrank - Parallel Stories
# ...      ...      ...                            ...
# 7746   s7745    Movie    Yours Sincerely, Kanan Gill
# 7750   s7749    Movie
# 7762   s7761    Movie                      Zaki Chan
# 7783   s7782    Movie                           Zoom
# 7784   s7783    Movie                           Zozo
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# 28    Sabina Fedeli, Anna Migotto
# ...                           ...
# 7746                 Neville Shah
# 7750            Ahmed Nader Galal
# 7762                   Wael Ihsan
# ...

# %% [markdown]
# ### Q.6 Show only the Titles of all TV Shows that were released in india only

# %% [markdown]
# #### Filtering

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demin Bichir, Hctor Bonilla, Oscar Serrano, Az...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_N  Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018

# %%
data[(data['Category']=='TV Show')&(data['Country']=='India')]['Title']
# Out:
# 132                                 7 (Seven)
# 2406                                    GHOUL
# 3119             Jamtara - Sabka Number Ayega
# 4724                          Paava Kadhaigal
# 6037    Th Eena Meena Deeka Chase Comedy Show
# Name: Title, dtype: object

# %% [markdown]
# ### Q.6. Show Top 10 Directors, who gave the highest number of TV Shows & Movie to Netflix?

# %% [markdown]
# #### value_counts()

# %%
data['Director'].value_counts().head(10)
# Out:
# Ral Campos, Jan S      18
# Marcus Raboy           15
# Jay Karas              14
# Cathy Garcia-Molina    13
# Martin Scorsese        12
# Jay Chapman            12
# Youssef Chahine        12
# Steven Spielberg       10
# David Dhawan            9
# Johnnie To              8
# Name: Director, dtype: int64

# %% [markdown]
# ### Q.7. Show all the Records, where 'Category is Movie and Type is Comedies'or'Country is United Kingdom'?

# %% [markdown]
# #### Filtering (And Or Operations)

# %%
data.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  Joï¿½ï¿½o Miguel, Bianca Comparato, Michel Gom...  Brazil    14-Aug-20
# 1  Demiï¿½ï¿½n Bichir, Hï¿½ï¿½ctor Bonilla, Oscar...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[((data['Category']=='Movie')&(data['Type']=='Comedies')) | (data['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                       Title  \
# 33       s34    Movie                #realityhigh
# 72       s73    Movie                    17 Again
# 82       s83    Movie         2036 Origin Unknown
# 84       s85    Movie                   21 & Over
# 93       s94    Movie           27: Gone Too Soon
# ...      ...      ...                         ...
# 7615   s7614    Movie  Why Are We Getting So Fat?
# 7623   s7622    Movie                   Wild Oats
# 7634   s7633    Movie                Wine Country
# 7664   s7663    Movie                     Work It
# 7725   s7724    Movie                You Can Tutu
#
#                                     Director  \
# 33                          Fernando Lebrija
# 72                               Burr Steers
# 82                             Hasraf Dulull
# 84                    Jon Lucas, Scott Moore
# 93                         Simon Napier-Bell
# ...                                      ...
# ...

# %% [markdown]
# ### Q.8.In how many movies/shows, Tom Cruise was cast?

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demin Bichir, Hctor Bonilla, Oscar Serrano, Az...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_N  Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018

# %% [markdown]
# #### Filtering

# %%
data[data['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860     1-Jan-20      R  189 min  Dramas, Independent Movies
# 5071     1-Jul-19      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N  Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019

# %% [markdown]
# ### Q.9.What are the different Ratings defined by Netflix?

# %% [markdown]
# #### nunique()

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demin Bichir, Hctor Bonilla, Oscar Serrano, Az...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_N  Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018

# %%
data['Rating'].nunique()
# Out:
# 14

# %% [markdown]
# #### nunique

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### Q.9.1 How many Movies got the 'TV-14' rating in Candas?

# %%
data.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 1  Demin Bichir, Hctor Bonilla, Oscar Serrano, Az...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#   Release_Date Rating Duration  \
# 1    23-Dec-16  TV-MA   93 min
# 2    20-Dec-18      R   78 min
# 3    16-Nov-17  PG-13   80 min
#
#                                                 Type  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          Description     Date_N  Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# ...

# %%
data[((data['Category']=='Movie')&(data['Rating']=='TV-14'))&(data['Country']=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 34                           Michael Kennedy
# 608                              Jason Stone
# 1506                           Jason Bourque
# 3713  Jennifer Baichwal, Nicholas de Pencier
# 3956                          Jean-Franois B
# ...

# %% [markdown]
# ### Q.9.2 How many TV Show got the 'R' rating after year 2018?

# %%
data[(data['Category']=='TV Show')&(data['Rating']=='R')&(data['Year']>=2018)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %% [markdown]
# ### Q.10 What is the maximum duration of a  Movie/Show on Netflix?

# %%
data['Duration'].unique()
# Out:
# array(['93 min', '78 min', '80 min', '123 min', '1 Season', '95 min',
#        '119 min', '118 min', '143 min', '103 min', '89 min', '91 min',
#        '149 min', '144 min', '124 min', '110 min', '128 min', '117 min',
#        '100 min', '99 min', '102 min', '104 min', '105 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '87 min', '109 min',
#        '101 min', '90 min', '113 min', '114 min', '130 min', '94 min',
#        '140 min', '135 min', '82 min', '70 min', '92 min', '164 min',
#        '83 min', '116 min', '84 min', '86 min', '120 min', '96 min',
#        '126 min', '75 min', '129 min', '77 min', '137 min', '148 min',
#        '121 min', '122 min', '176 min', '85 min', '22 min', '68 min',
#        '111 min', '29 min', '142 min', '168 min', '59 min', '108 min',
#        '44 min', '26 min', '156 min', '98 min', '57 min', '150 min',
#        '133 min', '115 min', '154 min', '127 min', '146 min', '136 min',
# ...

# %%
data.Duration.dtypes
# Out:
# dtype('O')

# %% [markdown]
# #### str.split()

# %%
data[['Minutes','Unit']]=data['Duration'].str.split(' ', expand=True)

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demin Bichir, Hctor Bonilla, Oscar Serrano, Az...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_N  Year Minutes  \
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016      93
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018      78
#
#   Unit
# 1  min
# 2  min

# %% [markdown]
# #### max()

# %%
data['Minutes'].max()
# Out:
# '99'

# %%
data.Minutes.min()
# Out:
# '1'

# %% [markdown]
# ### Q.11 Which individual country has the Highest No. of TV Shows?

# %%
data[data['Category']=='TV Show'].Country.value_counts().head(1)
# Out:
# United States    27
# Name: Country, dtype: int64

# %% [markdown]
# ### Q.12 How can we Sort the dataset by Year?

# %%
data.sort_values(by='Year').head(2)
# Out:
#      Show_Id Category                    Title              Director  \
# 7115   s7114    Movie     To and From New York  Sorin Dan Mihalcescu
# 3248   s3249    Movie  Just Another Love Story          Ole Bornedal
#
#                                                    Cast        Country  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 3248  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...        Denmark
#
#      Release_Date Rating Duration                                   Type  \
# 7115     1-Jan-08  TV-MA   81 min  Dramas, Independent Movies, Thrillers
# 3248     5-May-09  TV-MA  104 min           Dramas, International Movies
#
#                                             Description     Date_N  Year  \
# 7115  While covering a story in New York City, a Sea... 2008-01-01  2008
# 3248  When he causes a car accident that leaves a yo... 2009-05-05  2009
#
#      Minutes Unit
# 7115      81  min
# 3248     104  min

# %%
data.sort_values(by='Year', ascending=False).head(2)
# Out:
#      Show_Id Category               Title                         Director  \
# 6248   s6248    Movie  The Creative Brain  Jennifer Beamish, Toby Trackman
# 2349   s2350    Movie           Gangaajal                      Prakash Jha
#
#                                                    Cast        Country  \
# 6248                                     David Eagleman  United States
# 2349  Ajay Devgn, Gracy Singh, Mohan Agashe, Mohan J...          India
#
#      Release_Date Rating Duration                          Type  \
# 6248     1-Jan-21  TV-14   53 min                 Documentaries
# 2349     8-Jan-21  TV-MA  148 min  Dramas, International Movies
#
#                                             Description     Date_N  Year  \
# 6248  Neuroscientist David Eagleman taps into the cr... 2021-01-01  2021
# 2349  Posted to a small, crime-ridden town, a cop so... 2021-01-08  2021
#
#      Minutes Unit
# 6248      53  min
# 2349     148  min

# %% [markdown]
# ### Q.13 Find all the instances where:   Category is 'Movie' and Type is 'Dramas'  Or  Category is 'TV Show' & Type is 'Kids TV'

# %%
data[((data['Category']=='Movie')& (data['Type']=='Dramas')) | ((data['Category']=='TV Show')&(data['Type']=="Kids' TV"))]
# Out:
#      Show_Id Category                       Title          Director  \
# 4         s5    Movie                          21    Robert Luketic
# 7         s8    Movie                         187    Kevin Reynolds
# 170     s171    Movie                A Family Man     Mark Williams
# 232     s233    Movie  A Stoning in Fulham County     Larry Elikann
# 276     s277  TV Show                Abby Hatcher       Kyran Kelly
# ...      ...      ...                         ...               ...
# 7422   s7421    Movie                     Villain  Philip Barantini
# 7449   s7448    Movie                         VS.          Ed Lilly
# 7465   s7464    Movie                   Wakefield     Robin Swicord
# 7480   s7479    Movie                   War Horse  Steven Spielberg
# 7668   s7667  TV Show               World of Winx    Iginio Straffi
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
